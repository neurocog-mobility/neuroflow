# %% [markdown]
# # Neuroflow Development
# For documentation: https://neurocog-mobility.github.io/neuroflow-docs/

# %% [markdown]
# ## 1. Load NeuroFlow.

# %%
from neuroflow.utils.setup import initialize_neuroflow
from neuroflow.utils.setup import initialize_catalogs
import warnings
warnings.filterwarnings('ignore')

# SET NEUROFLOW PATH
NEUROFLOW_ROOT = r""
PROJECT_ROOT = r""

print("Path definitions set.")

initialize_neuroflow(NEUROFLOW_ROOT)

# %% [markdown]
# ## 2. Select a processing pipeline

# %%
from neuroflow.utils.app_pipeline import app_select_pipeline

app_select_pipeline()
# %run_viz

# %% [markdown]
# ## 3. Setup the data catalog

# %%
from neuroflow.utils.app_inputs import register_data_catalog

register_data_catalog(PROJECT_ROOT, NEUROFLOW_ROOT, pipeline_name)

# %% [markdown]
# ## 4. Setup the parameters catalog

# %%
from neuroflow.utils.app_params import register_params

register_params(PROJECT_ROOT, NEUROFLOW_ROOT, pipeline_name)

# %% [markdown]
# ## 5. Run NeuroFlow functions.
#
# See the tutorial on **Developing with NeuroFlow** to get started: https://neurocog-mobility.github.io/neuroflow/tutorials/dev-notebook/dev-notebook.html

# %%
## list the catalog dictionary
catalog
