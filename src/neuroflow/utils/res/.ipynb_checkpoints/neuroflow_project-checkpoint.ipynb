# %% [markdown]
# # Neuroflow Project
# For documentation: https://neurocog-mobility.github.io/neuroflow-docs/

# %% [markdown]
# ## 1. Load NeuroFlow:

# %%
from neuroflow.utils.setup import initialize_neuroflow
from neuroflow.utils.setup import initialize_catalogs
from neuroflow.utils.display import display_pipelines
import warnings
warnings.filterwarnings('ignore')

# SET NEUROFLOW PATH
NEUROFLOW_ROOT = ""
PROJECT_ROOT = ""

print("Path definitions set.")

initialize_neuroflow(NEUROFLOW_ROOT)
# Out:
# Path definitions set.
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:13                                                                                   │
# │                                                                                                  │
# │   10                                                                                             │
# │   11 print("Path definitions set.")                                                              │
# │   12                                                                                             │
# │ ❱ 13 initialize_neuroflow(NEUROFLOW_ROOT)                                                        │
# │   14                                                                                             │
# │                                                                                                  │
# │ /home/abdulzaf/github/development/neurocog-lab/neuroflow/src/neuroflow/utils/setup.py:123 in     │
# │ initialize_neuroflow                                                                             │
# │                                                                                                  │
# │   120 │   catalog_intermed = {str(key): info["catalog"] for key, info in intermeds.items()}      │
# │   121 │   catalog_data = {**catalog_inputs, **catalog_outputs, **catalog_intermed}               │
# │   122 │   catalog_params = {str(key): info["catalog"] for key, info in params.items()}           │
# │ ❱ 123 │   update_catalog(neuroflow_path, catalog_data, catalog_params)                           │
# │   124 │                                                                                          │
# │   125 │   print("-----------------------------------")                                           │
# │   126 │   print("-----------------------------------")                                           │
# │                                                                                                  │
# │ /home/abdulzaf/github/development/neurocog-lab/neuroflow/src/neuroflow/utils/setup.py:96 in      │
# │ update_catalog                                                                                   │
# │                                                                                                  │
# │    93 │   catalog_path = os.path.join(config_path, "catalog.yml")                                │
# │    94 │   parameters_path = os.path.join(config_path, "parameters.yml")                          │
# │    95 │                                                                                          │
# │ ❱  96 │   with open(catalog_path, 'w') as catalogfile:                                           │
# │    97 │   │   yaml.dump(dict_catalog, catalogfile, default_flow_style=False)                     │
# │    98 │                                                                                          │
# │    99 │   with open(parameters_path, 'w') as parametersfile:                                     │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: [Errno 2] No such file or directory: 'conf/base/catalog.yml'

# %% [markdown]
# ## 2. Explore available processing pipelines

# %%
display_pipelines()
# %run_viz

# %% [markdown]
# ## 3. Set data and parameter catalogs

# %%
# axivity:
# ~/Documents/data/neurocog-lab/test-data/naps/axivity
# sync:
# ~/Documents/data/neurocog-lab/test-data/naps/sync
pipeline_name = "summarize_step_data"

initialize_catalogs(pipeline_name, PROJECT_ROOT, NEUROFLOW_ROOT)
# Out:
# Reloaded config files.

# %% [markdown]
# ## 4. Run the pipeline

# %%
session.run(pipeline_name)
