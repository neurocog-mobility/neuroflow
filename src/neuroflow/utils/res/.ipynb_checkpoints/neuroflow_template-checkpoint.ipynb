# %% [markdown]
# # Neuroflow Project
# For documentation: https://neurocog-mobility.github.io/neuroflow-docs/
#
# ## 1. Set path definitions and load NeuroFlow:

# %%
from neuroflow.utils.setup import initialize_neuroflow
from neuroflow.utils.setup import initialize_catalogs
from neuroflow.pipeline_registry import display_pipelines
import warnings
warnings.filterwarnings('ignore')

# SET NEUROFLOW PATH
NEUROFLOW_ROOT = "/home/abdulzaf/github/development/neurocog-lab/neuroflow"
PROJECT_ROOT = "/home/abdulzaf/Documents/test"

print("Path definitions set.")

initialize_neuroflow(NEUROFLOW_ROOT)
# Out:
# Path definitions set.
# {'input_axivity_dataset': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'input_nimbal_pushoff': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'input_sync_dataset': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'out_axivity_rawplots': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'output_axivity_rawdata': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'output_axivity_rawplots': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'output_axivity_stepdata': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'output_axivity_stepplots': {'type': 'pandas.CSVDataset', 'filepath': ''}, 'output_axivity_stepsummary': {'type': 'pandas.CSVDataset', 'filepath': ''}} {'axivity_filepattern': 'placeholder', 'plot_imu': 'placeholder', 'step_parameters': 'placeholder', 'sync_filepattern': 'placeholder'}
# [02/21/25 22:04:15] INFO     Kedro project NeuroFlow                                                ]8;id=158391;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=143802;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=766084;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=78729;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py#145\145]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=125419;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=388825;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py#151\151]8;;\
# Updated config files.
# -----------------------------------
# -----------------------------------
# Neuroflow loaded successfully.
# -----------------------------------
# -----------------------------------

# %% [markdown]
# ## 2. Explore available processing pipelines

# %%
display_pipelines()
# %run_viz
# Out:
# Registered pipelines:
#
# process_raw_axivity
# 	Inputs:  ['input_axivity_dataset', 'input_sync_dataset']
# 	Parameters:  ['axivity_filepattern', 'sync_filepattern', 'plot_imu']
# 	Outputs:  ['output_axivity_rawdata', 'out_axivity_rawplots']
#
# process_step_data
# 	Inputs:  ['input_axivity_dataset', 'input_sync_dataset', 'input_nimbal_pushoff']
# 	Parameters:  ['axivity_filepattern', 'sync_filepattern', 'step_parameters', 'plot_imu']
# 	Outputs:  ['output_axivity_stepdata', 'output_axivity_stepplots']
#
# summarize_step_data
# 	Inputs:  ['input_axivity_dataset', 'input_sync_dataset', 'input_nimbal_pushoff']
# 	Parameters:  ['axivity_filepattern', 'sync_filepattern', 'step_parameters']
# 	Outputs:  ['output_axivity_stepsummary']
#
# project_naps
# 	Inputs:  ['input_axivity_dataset', 'input_sync_dataset', 'input_nimbal_pushoff']
# 	Parameters:  ['axivity_filepattern', 'sync_filepattern', 'step_parameters', 'plot_imu']
# 	Outputs:  ['output_axivity_rawdata', 'output_axivity_rawplots', 'output_axivity_stepdata', 'output_axivity_stepplots', 'output_axivity_stepsummary']
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <IPython.core.display.HTML object>
# [02/21/25 21:54:17] INFO     Using                               ]8;id=88995;file:///usr/local/lib/python3.10/dist-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=693308;file:///usr/local/lib/python3.10/dist-packages/kedro/framework/project/__init__.py#270\270]8;;\
#                              '/usr/local/lib/python3.10/dist-pac
#                              kages/kedro/framework/project/rich_
#                              logging.yml' as logging
#                              configuration.

# %%
# axivity:
# ~/Documents/data/neurocog-lab/test-data/naps/axivity
# sync:
# ~/Documents/data/neurocog-lab/test-data/naps/sync
pipeline_name = "summarize_step_data"

initialize_catalogs(pipeline_name, PROJECT_ROOT, NEUROFLOW_ROOT)
# Out:
# A data catalog for the summarize_step_data pipeline already exists.
# Would you like to overwrite the catalogs? (y/n) [n]:
# [02/21/25 22:04:18] INFO     Kedro project NeuroFlow                                                ]8;id=390115;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=588416;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py#144\144]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=372844;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=481233;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py#145\145]8;;\
#                              'pipelines'
#                     INFO     Registered line magic 'run_viz'                                        ]8;id=542955;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=927627;file:///usr/local/lib/python3.10/dist-packages/kedro/ipython/__init__.py#151\151]8;;\
# Reloaded config files.

# %% [markdown]
# ## RUN A PIPELINE
#
# Now we can choose a pipeline by its name and run it using the following command.

# %%
session.run(pipeline_name)
# Out:
# [02/21/25 22:04:21] INFO     Kedro project neuroflow                                                 ]8;id=363702;file:///usr/local/lib/python3.10/dist-packages/kedro/framework/session/session.py\session.py]8;;\:]8;id=439941;file:///usr/local/lib/python3.10/dist-packages/kedro/framework/session/session.py#329\329]8;;\
#                     INFO     Using synchronous mode for loading and saving data. Use the    ]8;id=44904;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=556107;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#68\68]8;;\
#                              --async flag for potential performance gains.
#                              https://docs.kedro.org/en/stable/nodes_and_pipelines/run_a_pip
#                              eline.html#load-and-save-asynchronously
#                     INFO     Loading data from input_axivity_dataset (IncrementalDataset)...    ]8;id=569758;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=175773;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from input_sync_dataset (IncrementalDataset)...       ]8;id=939533;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=497175;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from params:axivity_filepattern (MemoryDataset)...    ]8;id=897260;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=854089;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from params:sync_filepattern (MemoryDataset)...       ]8;id=508004;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=902754;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Running node: split_into_trials:                                           ]8;id=553418;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py\node.py]8;;\:]8;id=792421;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py#367\367]8;;\
#                              split_axivity_by_trial_timestamps([input_axivity_dataset;input_sync_datase
#                              t;params:axivity_filepattern;params:sync_filepattern]) ->
#                              [axivity_data_trials]
# Split into trials complete.
#                     INFO     Saving data to axivity_data_trials (MemoryDataset)...              ]8;id=249417;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=259163;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#431\431]8;;\
#                     INFO     Completed 1 out of 6 tasks                                     ]8;id=148258;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=873317;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#93\93]8;;\
#                     INFO     Loading data from axivity_data_trials (MemoryDataset)...           ]8;id=927569;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=60391;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from input_nimbal_pushoff (CSVDataset)...             ]8;id=837616;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=346493;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     WARNING  Unable to get file size for the dataset                                   ]8;id=467057;file:///usr/local/lib/python3.10/dist-packages/kedro_viz/integrations/kedro/hooks.py\hooks.py]8;;\:]8;id=145485;file:///usr/local/lib/python3.10/dist-packages/kedro_viz/integrations/kedro/hooks.py#165\165]8;;\
#                              CSVDataset(filepath=/home/abdulzaf/github/development/neurocog-lab/neurof
#                              low/data/nimbal_pushoff.csv, load_args={}, protocol=file,
#                              save_args={'index': False}): argument of type 'PurePosixPath' is not
#                              iterable
#                     INFO     Loading data from params:step_parameters (MemoryDataset)...        ]8;id=412642;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=19241;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Running node: nimbal_step_state_detection:                                 ]8;id=663147;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py\node.py]8;;\:]8;id=124192;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py#367\367]8;;\
#                              detect_steps_nimbal([axivity_data_trials;input_nimbal_pushoff;params:step_
#                              parameters]) -> [step_state_data]
# Step detection complete.
# [02/21/25 22:04:23] INFO     Saving data to step_state_data (MemoryDataset)...                  ]8;id=875399;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=941596;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#431\431]8;;\
#                     INFO     Completed 2 out of 6 tasks                                     ]8;id=457751;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=456060;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#93\93]8;;\
#                     INFO     Loading data from step_state_data (MemoryDataset)...               ]8;id=757076;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=523005;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Running node: extract_step_times: extract_steps([step_state_data]) ->      ]8;id=792217;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py\node.py]8;;\:]8;id=235452;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py#367\367]8;;\
#                              [table_step_times]
# Step extraction complete.
#                     INFO     Saving data to table_step_times (MemoryDataset)...                 ]8;id=522853;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=1953;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#431\431]8;;\
#                     INFO     Completed 3 out of 6 tasks                                     ]8;id=513379;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=87165;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#93\93]8;;\
#                     INFO     Loading data from step_state_data (MemoryDataset)...               ]8;id=445425;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=8705;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from table_step_times (MemoryDataset)...              ]8;id=441542;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=700509;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Running node: split_into_steps:                                            ]8;id=590543;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py\node.py]8;;\:]8;id=840368;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py#367\367]8;;\
#                              split_axivity_into_steps([step_state_data;table_step_times]) ->
#                              [axivity_data_steps]
# Split Axivity into steps complete.
# [02/21/25 22:04:25] INFO     Saving data to axivity_data_steps (MemoryDataset)...               ]8;id=79931;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=865471;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#431\431]8;;\
# [02/21/25 22:04:26] INFO     Completed 4 out of 6 tasks                                     ]8;id=286849;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=569770;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#93\93]8;;\
#                     INFO     Loading data from table_step_times (MemoryDataset)...              ]8;id=437211;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=414813;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from axivity_data_steps (MemoryDataset)...            ]8;id=943923;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=949364;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
# [02/21/25 22:04:27] INFO     Running node: summarize_step_data:                                         ]8;id=4464;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py\node.py]8;;\:]8;id=310793;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py#367\367]8;;\
#                              summarize_steps([table_step_times;axivity_data_steps]) ->
#                              [table_step_summaries]
# Step summary complete.
# [02/21/25 22:04:28] INFO     Saving data to table_step_summaries (MemoryDataset)...             ]8;id=2145;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=543140;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#431\431]8;;\
#                     INFO     Completed 5 out of 6 tasks                                     ]8;id=745208;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=649312;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#93\93]8;;\
#                     INFO     Loading data from table_step_summaries (MemoryDataset)...          ]8;id=268056;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=556097;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Running node: compile_step_info:                                           ]8;id=457252;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py\node.py]8;;\:]8;id=406917;file:///usr/local/lib/python3.10/dist-packages/kedro/pipeline/node.py#367\367]8;;\
#                              compile_step_summary([table_step_summaries]) ->
#                              [output_axivity_stepsummary]
# Step summary compilation complete.
#                     INFO     Saving data to output_axivity_stepsummary (CSVDataset)...          ]8;id=835553;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=144794;file:///usr/local/lib/python3.10/dist-packages/kedro/io/data_catalog.py#431\431]8;;\
#                     WARNING  Unable to get file size for the dataset                                   ]8;id=792295;file:///usr/local/lib/python3.10/dist-packages/kedro_viz/integrations/kedro/hooks.py\hooks.py]8;;\:]8;id=267756;file:///usr/local/lib/python3.10/dist-packages/kedro_viz/integrations/kedro/hooks.py#165\165]8;;\
#                              CSVDataset(filepath=/home/abdulzaf/Documents/test/data/processed/output_a
#                              xivity_stepsummary/axivity_step_summary.csv, load_args={}, protocol=file,
#                              save_args={'index': False}): argument of type 'PurePosixPath' is not
#                              iterable
#                     INFO     Completed 6 out of 6 tasks                                     ]8;id=184647;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py\sequential_runner.py]8;;\:]8;id=97576;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/sequential_runner.py#93\93]8;;\
#                     INFO     Pipeline execution completed successfully.                               ]8;id=415921;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/runner.py\runner.py]8;;\:]8;id=393359;file:///usr/local/lib/python3.10/dist-packages/kedro/runner/runner.py#115\115]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {}
